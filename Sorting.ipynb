# %% [markdown]
# Hello, and welcome to the programming portion of competitive STEM.
#
# Here you will learn some of the basics in coding in the python programming language.
#
# Anything that is written on a line after a pound sign '#' is a comment. This means that the computer will ignore the statement when running the code.

# %%
# Don't write in this section


print("This is how you print a line.")
print('You can also use single quotes.')

# You can print numbers and other objects
print(1234)
# Out:
# This is how you print a line.
# You can also use single quotes.
# 1234

# %% [markdown]
# Write in the next section the code neccesary to print a short message.

# %%
# Write your code here
# Out:
# This is my personal message

# %% [markdown]
# LISTS
#
# Lists in python are indexed starting with 0

# %%
mylist = ['a','b','c','d','e']

print(mylist[1]) #This will print b
# Out:
# b

# %% [markdown]
# Your assignment will be to sort a list that we provide, using the swap and comparison operators that are provided below.

# %%
# Do not modify this code

mylist = [1,7,3,4,5,6,2]

# swaps and comparisons are just counters we will use to measure how efficient your program is
swaps = 0
comparisons = 0

# This function will swap the a and b entries of a list
def swap(a,b):
    global swaps
    swaps += 1
    temp = mylist[a]
    mylist[a] = mylist[b]
    mylist[b] = temp

# This function will return true if the a entry is less than or equal to the b entry, false otherwise
def compare(a,b):
    global comparisons
    comparisons += 1
    return mylist[a] <= mylist[b]


print("The old list is as follows.")
print(mylist)

swap(1,6)

print("The new list after the swap is:")
print(mylist)
# Out:
# The old list is as follows.
# [1, 7, 3, 4, 5, 6, 2]
# The new list after the swap is:
# [1, 2, 3, 4, 5, 6, 7]

# %%
print(compare(1,2))
print(compare(2,1))
# Out:
# True
# False

# %% [markdown]
# You can use the following list to test your code.

# %%
mylist = [ 14, 67,   38,   86,   91,   69,   93,   64,    8,   16]

# %%
#Some useful python operations might include len, which returns the length of a list
print( len(mylist) )
# Out:
# 10

# %% [markdown]
# Your task is to write a program that will sort out mylist from lowest to highest. You will be judged based on how many times you need to use swap and compare to do this.
